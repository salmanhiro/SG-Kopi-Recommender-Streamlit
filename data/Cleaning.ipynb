# %%
import pandas as pd

# %%
df_sg = pd.read_csv("Grab SG Restaurants.csv")

# %%
df_sg
# Out:
#               id_source                         name  \
# 0             SGDD01085                Texas Chicken
# 1      4-CYTDLPUJEP53N6                       Subway
# 2             SGDD05605                     LiHO Tea
# 3             SGDD07548                     Wingstop
# 4      4-CY2ZLZLTT2EDJ2              Le Shrimp Ramen
# ...                 ...                          ...
# 16131  4-CZNFTYKKVA3UN2                 Minjiangkueh
# 16132         SGDD01192  The Modern Izakaya by Tatsu
# 16133         SGDD00961               Raj Restaurant
# 16134  4-C2AHJVATN7C2RE   Albismi Indian Muslim Food
# 16135  4-C2DXFEK2R6KJTJ  Zam Zam Indian Special Food
#
#                                                  address    country  \
# 0                               Texas Chicken - VivoCity  Singapore
# 1                                      Subway - Vivocity  Singapore
# 2                                   LiHO Tea - Vivo City  Singapore
# 3                                    Wingstop - VivoCity  Singapore
# 4                             Le Shrimp Ramen - Vivocity  Singapore
# ...                                                  ...        ...
# 16131                    Minjiangkueh - Ang Mo Kio Ave 3  Singapore
# 16132     The Modern Izakaya by Tatsu - Chijmes (#01-18)  Singapore
# 16133                     Raj Restaurant - SOHO @ Farrer  Singapore
# 16134        Albismi Indian Muslim Food - Woodlands Road  Singapore
# 16135  Zam Zam Indian Special Food - Yishun Industria...  Singapore
#
#                                                  cuisine currency  \
# 0      ["Western", "Fast Food", "Halal", "Chicken", "...      SGD
# 1      ["Healthy", "Sandwiches", "Fast Food", "Halal"...      SGD
# 2      ["Same Prices In-Store", "Beverages", "Local",...      SGD
# 3      ["Halal", "Chicken", "Fast Food", "Burger", "W...      SGD
# 4              ["Japanese", "Ramen", "Noodles", "Asian"]      SGD
# ...                                                  ...      ...
# 16131  ["Asian", "Bakery & Cake", "Breakfast & Brunch...      NaN
# 16132                   ["Japanese", "Noodles", "Grill"]      NaN
# 16133                ["Indian", "Dessert", "Vegetarian"]      SGD
# 16134                                         ["Indian"]      NaN
# 16135                                         ["Indian"]      NaN
#
#        delivery_cost       lat         lon  \
# 0              570.0  1.264792  103.822103
# 1              570.0  1.264741  103.822072
# 2              560.0  1.264309  103.821369
# 3              560.0  1.263527  103.821712
# 4              570.0  1.264810  103.822554
# ...              ...       ...         ...
# 16131            NaN  1.370340  103.843225
# 16132            NaN  1.295404  103.851698
# 16133          560.0  1.310830  103.852873
# 16134            NaN  1.396885  103.753440
# 16135            NaN  1.441651  103.831330
#
#                                            opening_hours  \
# 0      {"open": true, "displayedHours": "10:30-21:30"...
# 1      {"open": true, "displayedHours": "12:00-19:00"...
# 2      {"open": true, "displayedHours": "11:30-20:45"...
# 3      {"open": true, "displayedHours": "11:00-21:00"...
# 4      {"open": true, "displayedHours": "10:30-21:00"...
# ...                                                  ...
# 16131  {"displayedHours": "Closed", "sun": "Closed", ...
# 16132  {"displayedHours": "Closed", "sun": "12:00-14:...
# 16133  {"displayedHours": "Closed", "sun": "11:00-22:...
# 16134  {"displayedHours": "Closed", "sun": "09:00-22:...
# 16135  {"displayedHours": "Closed", "sun": "Closed", ...
#
#                                                image_url  radius  rating  \
# 0      https://d1sag4ddilekf6.cloudfront.net/compress...    5000     3.8
# 1      https://d1sag4ddilekf6.cloudfront.net/compress...    3000     4.2
# 2      https://d1sag4ddilekf6.cloudfront.net/compress...    5000     4.5
# 3      https://d1sag4ddilekf6.cloudfront.net/compress...    5000     4.4
# 4      https://d1sag4ddilekf6.cloudfront.net/compress...    5000     4.6
# ...                                                  ...     ...     ...
# 16131  https://d1sag4ddilekf6.cloudfront.net/compress...    5000     5.0
# 16132  https://d1sag4ddilekf6.cloudfront.net/compress...    3000     NaN
# 16133  https://d1sag4ddilekf6.cloudfront.net/compress...    3000     3.9
# 16134  https://d1sag4ddilekf6.cloudfront.net/compress...    5000     3.6
# 16135  https://d1sag4ddilekf6.cloudfront.net/compress...    5000     4.3
#
#        reviews_nr          delivery_options  \
# 0          1591.0             ONLY_DELIVERY
# 1           197.0             ONLY_DELIVERY
# 2           353.0         DELIVERY_TAKEAWAY
# 3          1391.0             ONLY_DELIVERY
# 4           309.0         DELIVERY_TAKEAWAY
# ...           ...                       ...
# 16131         2.0         DELIVERY_TAKEAWAY
# 16132         NaN         DELIVERY_TAKEAWAY
# 16133        72.0  DELIVERY_TAKEAWAY_DINEIN
# 16134        19.0         DELIVERY_TAKEAWAY
# 16135        37.0         DELIVERY_TAKEAWAY
#
#                                                    promo loc_type delivery_by  \
# 0      Use 'TEATIME' for FREE delivery between 3PM to...     FOOD        GRAB
# 1      Use 'TEATIME' for FREE delivery between 3PM to...     FOOD        GRAB
# 2      Use 'TEATIME' for FREE delivery between 3PM to...     FOOD        GRAB
# 3      Use 'TEATIME' for FREE delivery between 3PM to...     FOOD        GRAB
# 4      Use 'TEATIME' for FREE delivery between 3PM to...     FOOD        GRAB
# ...                                                  ...      ...         ...
# 16131                                                NaN     FOOD        GRAB
# 16132                                                NaN     FOOD        GRAB
# 16133                                                NaN     FOOD        GRAB
# 16134                                                NaN     FOOD        GRAB
# 16135  Use 'TEATIME' for FREE delivery between 3PM to...     FOOD        GRAB
#
#        delivery_time
# 0               43.0
# 1               42.0
# 2               41.0
# 3               45.0
# 4               44.0
# ...              ...
# 16131           26.0
# 16132           23.0
# 16133           26.0
# 16134           30.0
# 16135           27.0
#
# [16136 rows x 19 columns]

# %%
df_sg["cuisine"].str.contains('Coffee').sum()
# Out:
# 648

# %%
df_sg_coffee = df_sg[df_sg["cuisine"].str.contains('Coffee') ==True]

# %%
freq_sort = df_sg_coffee["name"].value_counts().index.tolist()

# %% [markdown]
# ## Get Mainstream Chain

# %%
popular = freq_sort[:4]

# %%
popular
# Out:
# ['Starbucks', 'Toast Box', 'Fun Toast', "Dunkin' Donuts"]

# %%
df_sg_coffee["is_mainstream_chain"] = 0
# Out:
# /tmp/ipykernel_18149/3357688535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["is_mainstream_chain"] = 0

# %%
for i in range(len(df_sg_coffee)):
    if df_sg_coffee["name"].iloc[i] in popular:
        df_sg_coffee["is_mainstream_chain"].iloc[i] = 1
        
    else:
        df_sg_coffee["is_mainstream_chain"].iloc[i] = 0
# Out:
# /tmp/ipykernel_18149/3641446469.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["is_mainstream_chain"].iloc[i] = 0
# /tmp/ipykernel_18149/3641446469.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["is_mainstream_chain"].iloc[i] = 1

# %%
df_sg_coffee["is_mainstream_chain"].value_counts()
# Out:
# 0    544
# 1    104
# Name: is_mainstream_chain, dtype: int64

# %%
df_sg_coffee["opening_hours"].iloc[10]
# Out:
# '{"open": true, "displayedHours": "07:30-15:30", "sun": "07:30-15:30", "mon": "07:30-15:30", "tue": "07:30-15:30", "wed": "07:30-15:30", "thu": "07:30-15:30", "fri": "07:30-15:30", "sat": "07:30-15:30"}'

# %%
import json

json_ex = json.loads(df_sg_coffee["opening_hours"].iloc[0])

# %%
# Define a function to extract the data from the column
def extract_hours(idxrow):
    json_ex = json.loads(row["opening_hours"].iloc[i])
    for day in ['sun', 'mon', 'tue', 'wed', 'thu', 'fri', 'sat']:
        open_col = f"{day}_open"
        close_col = f"{day}_close"
        row[open_col] = hours[day].split("-")[0]
        row[close_col] = hours[day].split("-")[1]
        print("done")
    return row

# %%
json_ex = json.loads(df_sg_coffee["opening_hours"].iloc[i])
json_ex["sun"]
# Out:
# {'displayedHours': 'Closed',
#  'sun': '10:30-22:00',
#  'mon': '10:30-22:00',
#  'tue': '10:30-22:00',
#  'wed': '10:30-22:00',
#  'thu': '10:30-22:00',
#  'fri': '10:30-22:00',
#  'sat': '10:30-22:00'}

# %%
df_sg_coffee["mon_open"] = ""
df_sg_coffee["mon_close"] = ""
df_sg_coffee["tue_open"] = ""
df_sg_coffee["tue_close"] = ""
df_sg_coffee["wed_open"] = ""
df_sg_coffee["wed_close"] = ""
df_sg_coffee["thu_open"] = ""
df_sg_coffee["thu_close"] = ""
df_sg_coffee["fri_open"] = ""
df_sg_coffee["fri_close"] = ""
df_sg_coffee["sat_open"] = ""
df_sg_coffee["sat_close"] = ""
df_sg_coffee["sun_open"] = ""
df_sg_coffee["sun_close"] = ""
# Out:
# /tmp/ipykernel_18149/3011510798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["mon_open"] = ""
# /tmp/ipykernel_18149/3011510798.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["mon_close"] = ""
# /tmp/ipykernel_18149/3011510798.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["tue_open"] = ""
# /tmp/ipykernel_18149/3011510798.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["tue_close"] = ""
# /tmp/ipykernel_18149/3011510798.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["wed_open"] = ""
# /tmp/ipykernel_18149/3011510798.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["wed_close"] = ""
# /tmp/ipykernel_18149/3011510798.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["thu_open"] = ""
# /tmp/ipykernel_18149/3011510798.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["thu_close"] = ""
# /tmp/ipykernel_18149/3011510798.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["fri_open"] = ""
# /tmp/ipykernel_18149/3011510798.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["fri_close"] = ""
# /tmp/ipykernel_18149/3011510798.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["sat_open"] = ""
# /tmp/ipykernel_18149/3011510798.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["sat_close"] = ""
# /tmp/ipykernel_18149/3011510798.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["sun_open"] = ""
# /tmp/ipykernel_18149/3011510798.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee["sun_close"] = ""

# %%
from tqdm import tqdm

days = ["mon", "tue", "wed", "thu", "fri", "sat", "sun"]

for row in tqdm(range(len(df_sg_coffee))):
    json_ex = json.loads(df_sg_coffee["opening_hours"].iloc[row])
    for day in days:
        try:
            hours = json_ex[day].split("-")
            if hours is not None:
                df_sg_coffee[day + "_open"].iloc[row] = datetime.strptime(hours[0], '%H:%M')
                df_sg_coffee[day + "_close"].iloc[row] = datetime.strptime(hours[1], '%H:%M')
            else:
                df_sg_coffee[day + "_open"].iloc[row] = None
                df_sg_coffee[day + "_close"].iloc[row] = None
        except:
            pass
# Out:
#   0%|                                                   | 0/648 [00:00<?, ?it/s]/tmp/ipykernel_18149/98257104.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee[day + "_open"].iloc[row] = datetime.strptime(hours[0], '%H:%M')
# /tmp/ipykernel_18149/98257104.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sg_coffee[day + "_close"].iloc[row] = datetime.strptime(hours[1], '%H:%M')
# 100%|████████████████████████████████████████| 648/648 [00:03<00:00, 203.52it/s]

# %%
df_sg_coffee
# Out:
#               id_source                name  \
# 5      4-C2L2AKNYEENBVX              Heytea
# 35     4-CZJ1L3BWJLMUA2           Toast Box
# 76            SGDD07935      Dunkin' Donuts
# 112    4-C2DCCYVCRBDECJ           Starbucks
# 119    4-C2TTNJMYDCJUR2  The Pup's Boutique
# ...                 ...                 ...
# 15887         SGDD11186           Toast Box
# 15904  4-CZLKKGNZRT2WEJ    Bettr Coffee Co.
# 15928         SGDD07928      Dunkin' Donuts
# 15938         SGDD11406           Starbucks
# 16068  4-C2L2RKVBVJVAAT          Tenderbest
#
#                                           address    country  \
# 5          HEYTEA Vivo City [Islandwide Delivery]  Singapore
# 35                   Toast Box - VivoCity #03-01D  Singapore
# 76           Dunkin' Donuts - Harbourfront Centre  Singapore
# 112               Starbucks - Harbourfront Centre  Singapore
# 119             The Pup's Boutique - Silat Avenue  Singapore
# ...                                           ...        ...
# 15887                  Toast Box - Waterway Point  Singapore
# 15904  Bettr Coffee Co. - Khoo Teck Puat Hospital  Singapore
# 15928             Dunkin' Donuts - Causeway Point  Singapore
# 15938          Starbucks - Woodlands Exchange Mrt  Singapore
# 16068                Tenderbest - Canberra Street  Singapore
#
#                                                  cuisine currency  \
# 5      ["Beverages", "Bubble Tea", "Coffee & Tea", "D...      SGD
# 35               ["Local", "Coffee & Tea", "Sandwiches"]      SGD
# 76     ["Snack", "Coffee", "Bakery", "Beverages", "Tea"]      SGD
# 112                                     ["Coffee & Tea"]      SGD
# 119    ["Asian", "Bakery & Cake", "Coffee & Tea", "Pa...      SGD
# ...                                                  ...      ...
# 15887  ["Beverages", "Local", "Coffee", "Sandwiches",...      SGD
# 15904              ["Mart", "Coffee", "Local", "Snacks"]      SGD
# 15928  ["Snack", "Coffee", "Bakery", "Beverages", "Tea"]      SGD
# 15938  ["Beverages", "Snack", "Coffee", "Bakery", "Tea"]      SGD
# 16068  ["Fried Chicken", "Pasta", "Western", "Coffee"...      SGD
#
#        delivery_cost       lat         lon  \
# 5              730.0  1.263884  103.822201
# 35             560.0  1.264770  103.821907
# 76             580.0  1.264330  103.820117
# 112            730.0  1.264789  103.820107
# 119            580.0  1.277220  103.831060
# ...              ...       ...         ...
# 15887          330.0  1.406698  103.902275
# 15904          199.0  1.424464  103.838016
# 15928         1990.0  1.435883  103.785845
# 15938         2040.0  1.436613  103.786742
# 16068         2340.0  1.446341  103.834179
#
#                                            opening_hours  ...  \
# 5      {"open": true, "displayedHours": "11:00-22:00"...  ...
# 35     {"open": true, "displayedHours": "09:00-19:00"...  ...
# 76     {"open": true, "displayedHours": "10:00-20:30"...  ...
# 112    {"open": true, "displayedHours": "08:00-20:30"...  ...
# 119    {"open": true, "displayedHours": "11:00-19:00"...  ...
# ...                                                  ...  ...
# 15887  {"displayedHours": "Closed", "sun": "08:10-20:...  ...
# 15904  {"displayedHours": "Closed", "sun": "Closed", ...  ...
# 15928  {"displayedHours": "Closed", "sun": "10:00-22:...  ...
# 15938  {"displayedHours": "Closed", "sun": "08:30-21:...  ...
# 16068  {"displayedHours": "Closed", "sun": "10:30-22:...  ...
#
#                   wed_open            wed_close             thu_open  \
# 5      1900-01-01 12:00:00  1900-01-01 21:30:00  1900-01-01 12:00:00
# 35     1900-01-01 09:00:00  1900-01-01 19:00:00  1900-01-01 09:00:00
# 76     1900-01-01 10:00:00  1900-01-01 20:30:00  1900-01-01 10:00:00
# 112    1900-01-01 09:00:00  1900-01-01 19:30:00  1900-01-01 08:00:00
# 119    1900-01-01 11:00:00  1900-01-01 19:00:00  1900-01-01 11:00:00
# ...                    ...                  ...                  ...
# 15887  1900-01-01 08:10:00  1900-01-01 20:30:00  1900-01-01 08:10:00
# 15904  1900-01-01 08:00:00  1900-01-01 17:00:00  1900-01-01 08:00:00
# 15928  1900-01-01 10:00:00  1900-01-01 22:00:00  1900-01-01 10:00:00
# 15938  1900-01-01 07:30:00  1900-01-01 21:30:00  1900-01-01 07:30:00
# 16068  1900-01-01 10:30:00  1900-01-01 22:00:00  1900-01-01 10:30:00
#
#                  thu_close             fri_open            fri_close  \
# 5      1900-01-01 21:20:00  1900-01-01 11:00:00  1900-01-01 21:50:00
# 35     1900-01-01 19:00:00  1900-01-01 09:00:00  1900-01-01 19:00:00
# 76     1900-01-01 20:30:00  1900-01-01 10:00:00  1900-01-01 20:30:00
# 112    1900-01-01 19:30:00  1900-01-01 08:00:00  1900-01-01 20:30:00
# 119    1900-01-01 19:00:00  1900-01-01 11:00:00  1900-01-01 19:00:00
# ...                    ...                  ...                  ...
# 15887  1900-01-01 20:30:00  1900-01-01 08:10:00  1900-01-01 20:30:00
# 15904  1900-01-01 17:00:00  1900-01-01 08:00:00  1900-01-01 17:00:00
# 15928  1900-01-01 22:00:00  1900-01-01 10:00:00  1900-01-01 22:00:00
# 15938  1900-01-01 21:30:00  1900-01-01 07:30:00  1900-01-01 21:30:00
# 16068  1900-01-01 22:00:00  1900-01-01 10:30:00  1900-01-01 22:00:00
#
#                   sat_open            sat_close            sun_close  \
# 5      1900-01-01 11:00:00  1900-01-01 22:00:00  1900-01-01 22:00:00
# 35     1900-01-01 09:00:00  1900-01-01 19:00:00  1900-01-01 19:00:00
# 76     1900-01-01 10:00:00  1900-01-01 20:30:00  1900-01-01 20:30:00
# 112    1900-01-01 08:00:00  1900-01-01 20:30:00  1900-01-01 19:30:00
# 119    1900-01-01 11:00:00  1900-01-01 19:00:00  1900-01-01 19:00:00
# ...                    ...                  ...                  ...
# 15887  1900-01-01 08:10:00  1900-01-01 20:30:00  1900-01-01 20:30:00
# 15904
# 15928  1900-01-01 10:00:00  1900-01-01 22:00:00  1900-01-01 22:00:00
# 15938  1900-01-01 08:30:00  1900-01-01 21:30:00  1900-01-01 21:30:00
# 16068  1900-01-01 10:30:00  1900-01-01 22:00:00  1900-01-01 22:00:00
#
#                   sun_open
# 5      1900-01-01 11:00:00
# 35     1900-01-01 09:00:00
# 76     1900-01-01 10:00:00
# 112    1900-01-01 08:00:00
# 119    1900-01-01 11:00:00
# ...                    ...
# 15887  1900-01-01 08:10:00
# 15904
# 15928  1900-01-01 10:00:00
# 15938  1900-01-01 08:30:00
# 16068  1900-01-01 10:30:00
#
# [648 rows x 34 columns]

# %%
df_sg_coffee.to_csv("full_sg_kopi.csv", index=None)

# %%
df_pa = pd.read_csv("sg_PA.csv")

# %%
df_pa.columns = ['Name', 'Malay', 'Chinese', 'Pinyin', 'Tamil', 'Region','Area', 'Population', 'Density']

# %%
df_pa["lat"] = 0
df_pa["lon"] = 0

# %%
# try to get location

import requests
import urllib.parse

for i in range (len(df_pa)):
    index = df_pa["Name"].iloc[i]
    address = f"{index}, Singapore"
    url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(address) +'?format=json'

    response = requests.get(url).json()
    print(address)
    print(response[0]["lat"])
    print(response[0]["lon"])
    df_pa["lat"].iloc[i] = response[0]["lat"]
    df_pa["lon"].iloc[i] = response[0]["lon"]
# Out:
# Ang Mo Kio, Singapore
# 1.3700803
# 103.8495228
# Bedok, Singapore
# 1.3239765
# 103.930216
# Bishan, Singapore
# 1.3509859
# 103.84825507492937
# Boon Lay, Singapore
# 1.3385504
# 103.7058124
# Bukit Batok, Singapore
# 1.3490572
# 103.7495906
# Bukit Merah, Singapore
# 1.2837356
# 103.8200999
# Bukit Panjang, Singapore
# 1.3791486
# 103.76141301431002
# Bukit Timah, Singapore
# 1.3546901
# 103.7763724
# Central Water Catchment, Singapore
# 1.3700592
# 103.8034477
# Changi, Singapore
# 1.3539247
# 103.9746973
# Changi Bay, Singapore
# 1.3168496
# 104.0206494
# Choa Chu Kang, Singapore
# 1.3847493
# 103.7445341
# Clementi, Singapore
# 1.3151003
# 103.7652311
# Downtown Core, Singapore
# 1.2862423
# 103.8537756
# Geylang, Singapore
# 1.3181862
# 103.8870563
# Hougang, Singapore
# 1.3708011
# 103.89254433997465
# Jurong East, Singapore
# 1.333108
# 103.7422939
# Jurong West, Singapore
# 1.3434392
# 103.7058663
# Kallang, Singapore
# 1.310759
# 103.866262
# Lim Chu Kang, Singapore
# 1.4342172
# 103.7149872
# Mandai, Singapore
# 1.4235346
# 103.8033499
# Marina East, Singapore
# 1.288624
# 103.869827
# Marina South, Singapore
# 1.2772674
# 103.8658786
# Marine Parade, Singapore
# 1.3026889
# 103.9073952
# Museum, Singapore
# 1.2956562
# 103.8467218
# Newton, Singapore
# 1.31318325
# 103.83804024301281
# North-Eastern Islands, Singapore
# 1.4091352
# 104.0267733
# Novena, Singapore
# 1.3205257000000001
# 103.84388133927948
# Orchard, Singapore
# 1.30312075
# 103.8313759279562
# Outram, Singapore
# 1.2816642
# 103.840653
# Pasir Ris, Singapore
# 1.3730307
# 103.949255
# Paya Lebar, Singapore
# 1.3174795000000001
# 103.89235252467483
# Pioneer, Singapore
# 1.3375884
# 103.6974104
# Punggol, Singapore
# 1.4051559
# 103.90236801879885
# Queenstown, Singapore
# 1.2946226
# 103.8060366
# River Valley, Singapore
# 1.2976832
# 103.834188
# Rochor, Singapore
# 1.3039183
# 103.85278854599449
# Seletar, Singapore
# 1.4098488
# 103.8773789
# Sembawang, Singapore
# 1.4490928
# 103.8200555
# Sengkang, Singapore
# 1.3919236499999998
# 103.89549093760694
# Serangoon, Singapore
# 1.3497610500000001
# 103.87368414801405
# Simpang, Singapore
# 1.4452954
# 103.8497425
# Singapore River, Singapore
# 1.28917835
# 103.84515431766008
# Southern Islands, Singapore
# 1.2276088
# 103.8436701
# Straits View, Singapore
# 1.2734811
# 103.8596111
# Sungei Kadut, Singapore
# 1.4149971
# 103.7533106
# Tampines, Singapore
# 1.3546528
# 103.9435712
# Tanglin, Singapore
# 1.30420465
# 103.81847174837526
# Tengah, Singapore
# 1.3655284
# 103.7307585
# Toa Payoh, Singapore
# 1.3353906
# 103.8497414
# Tuas, Singapore
# 1.3293722
# 103.6482364
# Western Islands, Singapore
# 1.2331839
# 103.7309357
# Western Water Catchment, Singapore
# 1.3487577
# 103.6784309
# Woodlands, Singapore
# 1.436897
# 103.786216
# Yishun, Singapore
# 1.4293839
# 103.8350282

# %%
df_pa.to_csv("sg_pa_w_coord.csv", index=None)

# %%
# http://maps.google.com/maps/dir/1.20,+103.8221/51.3841,-114.01679
